# %%
# directory business etc.
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# %%
import os
os.chdir('/content/gdrive/MyDrive/PhylogeneticAnalysis')
# !pwd

# %%
# %pip install rdflib
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn

# %%
from rdflib import Graph
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
segments = pd.read_csv('DTL_1000_segmentations.csv', sep=';')
segments.head()

# %%
raw_data = pd.read_json('dtl_1000.json')
raw_data.shape

# %%
raw_data.head()

# %%
metadata = pd.json_normalize(data=raw_data['segment_#DTL_1000_segmentations_csv'])
metadata.head(-5)

# %%
segments = pd.DataFrame(seg for seg in raw_data['segment_#DTL_1000_segmentations_csv'])
segments.head()

# %%
with open('dtl_1000.json', 'r') as f:
  data = json.load(f)

# %%
data[4]

# %%
import sqlite3

    # Create a SQL connection to our SQLite database
con = sqlite3.connect('wjazzd.db')

cur = con.cursor()

cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cur.fetchall())

    # The result of a "cursor.execute" can be iterated over by row
# for row in cur.execute("SELECT * FROM "):
#   print(row)

    # Be sure to close the connection
con.close()

# %%
g = Graph()
g.parse('dtl1000.ttl')

# %%
print(f'graph has {len(g)} facts')

# %%
import pprint
for stmt in g:
    pprint.pprint(stmt)

# %%
for index, (sub, pred, obj) in enumerate(g):
  print(sub, pred, obj)
  if index == 10:
    break
